# %%
import random
import hangman_stages
# word_list =['apple', 'beautiful', 'potato']
# lives = 6 ## as of game condition/

# %%
# ## generating a word
# chosen_word = random.choice(word_list)
# print(chosen_word)

# %%
# ## generating as many blank as letters in words

# display=[] 

# for i in range(len(chosen_word)):
#     display += '_'

# print(display)

# %%
# ## asking user to guess a word
# guessed_letter = input("guess a letter").lower()  ## lower bcz we have taken words in lowercase

# %%
# ## checking if the guessed letter in the word or not ?

# for letter in chosen_word:
#     if guessed_letter ==letter:
#         print('matched')
#     else:
#         print('not matched')

# %%
# #### checking if the guessed letter in the word or not ?
# ## but we want to guess the letter again and again
# ##For this we use ------>we use WHILE LOOP

# game_over = False

# while not game_over:
#     guessed_letter = input("guess a letter").lower()
#     for letters in chosen_word:
#         if guessed_letter ==letters:  ## Yes guessed letter in the word
#             print('matched')
#     else:                            ## No guessed letter in the word
#         print('not matched')

# %%
# ## If the guessed letter(guessed) is in the word 
# ## Replace Blank With ----> guessed letter
# ## we have to use For loop for position 

# game_over = False

# while not game_over:
#     # for letter in chosen_word:
#     guessed_letter = input("guess a letter").lower()
#     for position in range(len(chosen_word)):
        
#         letter = chosen_word[position] ## we have to get the letter at that position
        
#         if letter == guessed_letter:  
#             display[position] = guessed_letter      ## replacing  Blank with guessed letter
            
#         else:                            
#             print('not matched')

# %%
# ## if the guessed letter in not in the word
# ## You will loose a life
# ## also check for out of lives, if yes then game over will be true


# game_over = False

# while not game_over:
#     # for letter in chosen_word:
#     guessed_letter = input("guess a letter").lower()
#     for position in range(len(chosen_word)):
        
#         letter = chosen_word[position] ## we have to get the letter at that position
        
#         if letter == guessed_letter:  
#             display[position] = guessed_letter      ## replacing  Blank with guessed letter
#     print(display)
    
#         # else:                            
#         #     lives =-1  ## not using else here bcz for a single guess it will match with all the position of choosen word and remove life which is not good
#     if guessed_letter not in chosen_word:
#         lives -=1
#         if lives == 0:
#             game_over = True
#             print('you loose')

# %%
# ## check if all  the blanks are filled or not? 

# game_over = False

# while not game_over:
#     # for letter in chosen_word:
#     guessed_letter = input("guess a letter").lower()
#     for position in range(len(chosen_word)):
        
#         letter = chosen_word[position] ## we have to get the letter at that position
        
#         if letter == guessed_letter:  
#             display[position] = guessed_letter      ## replacing  Blank with guessed letter
#     print(display) 
#         # else:                            
#         #     lives =-1  ## not using else here bcz for a single guess it will match with all the position of choosen word and remove life which is not good
    
#     ## losing a life
#     if guessed_letter not in chosen_word:
#         lives -=1
#         if lives == 0:
#             game_over = True
#             print('you loose')
            
#     ## checking all the Balnks are replaced or not
    
#     if '- ' not in display:
#         game_over = True
#         print(' you win')

# %%
word_list =['apple', 'beautiful', 'potato']
lives = 6 
print('Initial lives' , lives)

chosen_word = random.choice(word_list)
print(chosen_word)

display=[] 
for i in range(len(chosen_word)):
    display += '_'
print(display)

game_over = False

while not game_over:
    guessed_letter = input("guess a letter").lower()
    print('\nGuessed letter: ', guessed_letter)
    
    for position in range(len(chosen_word)):
        letter = chosen_word[position]  
        
        if letter == guessed_letter:  
            display[position] = guessed_letter       
    print(display)       
 
 
    if guessed_letter not in chosen_word:
        lives -=1
        print('lives left:', lives)
        if lives == 0:
            game_over = True
            print('you loose')
            
    if '_' not in display:
        game_over = True
        print(' you win')
    print(hangman_stages.stages[lives])
# Out:
# Initial lives 6
# potato
# ['_', '_', '_', '_', '_', '_']
#
# Guessed letter:  p
# ['p', '_', '_', '_', '_', '_']
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
#
# Guessed letter:  v
# ['p', '_', '_', '_', '_', '_']
# lives left: 5
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
#
# Guessed letter:  w
# ['p', '_', '_', '_', '_', '_']
# lives left: 4
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
#
# Guessed letter:  w
# ['p', '_', '_', '_', '_', '_']
# lives left: 3
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
#
#
#
# Guessed letter:  w
# ['p', '_', '_', '_', '_', '_']
# lives left: 2
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
#
#
#
# Guessed letter:  w
# ['p', '_', '_', '_', '_', '_']
# lives left: 1
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
#
#
# Guessed letter:  w
# ['p', '_', '_', '_', '_', '_']
# lives left: 0
# you loose
#
#
#   +---+
#   |   |
#   O   |
#  /|\  |
# ...
