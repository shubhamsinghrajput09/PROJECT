# %%
import game_art
import game_database
import random

# %%
print(game_art.game_logo)


account1 = random.choice(game_database.data)
account2 = random.choice(game_database.data)

name = account1['name']
description = account1['description']
followers = account1['follower_count']
country = account1['country']
print(f" {name} , a {description} , from {country}")
# Out:
#   _    _ _       _                 _                               _____
#  | |  | (_)     | |               | |                             / ____|
#  | |__| |_  __ _| |__   ___ _ __  | |     _____      _____ _ __  | |  __  __ _ _ __ ___   ___
#  |  __  | |/ _` | '_ \ / _ \ '__| | |    / _ \ \ /\ / / _ \ '__| | | |_ |/ _` | '_ ` _ \ / _ \
#  | |  | | | (_| | | | |  __/ |    | |___| (_) \ V  V /  __/ |    | |__| | (_| | | | | | |  __/
#  |_|  |_|_|\__, |_| |_|\___|_|    |______\___/ \_/\_/ \___|_|     \_____|\__,_|_| |_| |_|\___|
#             __/ |
#            |___/
#
#
#   Pankaj Tripathi  , a  Actor  , from  India

# %%
print(game_art.game_logo)






def display_account(account):
    name = account['name']
    description = account['description']
    followers = account['follower_count']
    country = account['country']
    print(f" {name} , a {description} , from {country}")

account1 = random.choice(game_database.data)
account2 = random.choice(game_database.data)

display_account(account1)
display_account(account2)
# Out:
#   _    _ _       _                 _                               _____
#  | |  | (_)     | |               | |                             / ____|
#  | |__| |_  __ _| |__   ___ _ __  | |     _____      _____ _ __  | |  __  __ _ _ __ ___   ___
#  |  __  | |/ _` | '_ \ / _ \ '__| | |    / _ \ \ /\ / / _ \ '__| | | |_ |/ _` | '_ ` _ \ / _ \
#  | |  | | | (_| | | | |  __/ |    | |___| (_) \ V  V /  __/ |    | |__| | (_| | | | | | |  __/
#  |_|  |_|_|\__, |_| |_|\___|_|    |______\___/ \_/\_/ \___|_|     \_____|\__,_|_| |_| |_|\___|
#             __/ |
#            |___/
#
#
#   shubham's Lecture , a  Youtuber  , from  India
#   Shakira  , a  Musician  , from  Colombia

# %%
print(game_art.game_logo)






def display_account(account):
    name = account['name']
    description = account['description']
    followers = account['follower_count']
    country = account['country']
    return f" {name} , a {description} , from {country}"

account1 = random.choice(game_database.data)
account2 = random.choice(game_database.data)

print(f" Compare 1: {display_account(account1)}")

print(game_art.vs)

print(f" Compare 2: {display_account(account2)}")
# Out:
#   _    _ _       _                 _                               _____
#  | |  | (_)     | |               | |                             / ____|
#  | |__| |_  __ _| |__   ___ _ __  | |     _____      _____ _ __  | |  __  __ _ _ __ ___   ___
#  |  __  | |/ _` | '_ \ / _ \ '__| | |    / _ \ \ /\ / / _ \ '__| | | |_ |/ _` | '_ ` _ \ / _ \
#  | |  | | | (_| | | | |  __/ |    | |___| (_) \ V  V /  __/ |    | |__| | (_| | | | | | |  __/
#  |_|  |_|_|\__, |_| |_|\___|_|    |______\___/ \_/\_/ \___|_|     \_____|\__,_|_| |_| |_|\___|
#             __/ |
#            |___/
#
#
#  Compare 1:   Justin Bieber  , a  Musician  , from  Canada
#
#  __      __   _____
#  \ \    / /  / ____|
#   \ \  / /  | (___
#    \ \/ /    \___ \
#     \  /     ____) |
#      \/     |_____/
#
#
#  Compare 2:   Jennifer Lopez  , a  Musician and Actress  , from  United States

# %%
print(game_art.game_logo)


def display_account(account):
    name = account['name']
    description = account['description']
    country = account['country']
    return f" {name} , a {description} , from {country}"

account1 = random.choice(game_database.data)
account2 = random.choice(game_database.data)

print(f"Compare 1: {display_account(account1)}")
print(game_art.vs)
print(f"Compare 2: {display_account(account2)}")


guess = int(input("who has more Followers? 1 or 2: "))

followers_count_1 = account1['follower_count']
followers_count_2 = account2['follower_count']


score =0
if followers_count_1 > followers_count_2 and guess==1:
    score += 1
    
elif followers_count_1 > followers_count_2 and guess==2:
    print("you guessed wrong , you loose")
    
elif followers_count_1 < followers_count_2 and guess==1:
    print("you guessed wrong , you loose")
    
elif followers_count_1 < followers_count_2 and guess==2:
    score += 1

else :
    score +=1
    
print(score)
# Out:
#   _    _ _       _                 _                               _____
#  | |  | (_)     | |               | |                             / ____|
#  | |__| |_  __ _| |__   ___ _ __  | |     _____      _____ _ __  | |  __  __ _ _ __ ___   ___
#  |  __  | |/ _` | '_ \ / _ \ '__| | |    / _ \ \ /\ / / _ \ '__| | | |_ |/ _` | '_ ` _ \ / _ \
#  | |  | | | (_| | | | |  __/ |    | |___| (_) \ V  V /  __/ |    | |__| | (_| | | | | | |  __/
#  |_|  |_|_|\__, |_| |_|\___|_|    |______\___/ \_/\_/ \___|_|     \_____|\__,_|_| |_| |_|\___|
#             __/ |
#            |___/
#
#
# Compare 1:   NASA  , a  Space Agency  , from  United States
#
#  __      __   _____
#  \ \    / /  / ____|
#   \ \  / /  | (___
#    \ \/ /    \___ \
#     \  /     ____) |
#      \/     |_____/
#
#
# Compare 2:   Narendra Modi  , a  Prime Minister , from India
# you guessed wrong , you loose
# 0

# %%
print(game_art.game_logo)
score = 0



def display_account(account):
    name = account['name']
    description = account['description']
    country = account['country']
    return f" {name} , a {description} , from {country}"


def check_answer( followers_count_1 , followers_count_2 , guess):
    if followers_count_1 < followers_count_2:
        if guess == 1: ##return guess==2
            return False
        else:
            return True
        
    else:
        if guess==1:
            return True
        else:
            return False



account1 = random.choice(game_database.data)
account2 = random.choice(game_database.data)

print(f"Compare 1: {display_account(account1)}")  # function call
print(game_art.vs)
print(f"Compare 2: {display_account(account2)}")  # function call 


guess = int(input("who has more Followers? 1 or 2: "))

followers_count_1 = account1['follower_count']
followers_count_2 = account2['follower_count']



is_corrrect = check_answer(followers_count_1 , followers_count_2 , guess )  ## function call

if is_corrrect == True:
    score +=1
    print(f"you are right. Your score is: {score}")
    
else:
    print(f"You are wrong.. your final score is: {score}")
# Out:
#   _    _ _       _                 _                               _____
#  | |  | (_)     | |               | |                             / ____|
#  | |__| |_  __ _| |__   ___ _ __  | |     _____      _____ _ __  | |  __  __ _ _ __ ___   ___
#  |  __  | |/ _` | '_ \ / _ \ '__| | |    / _ \ \ /\ / / _ \ '__| | | |_ |/ _` | '_ ` _ \ / _ \
#  | |  | | | (_| | | | |  __/ |    | |___| (_) \ V  V /  __/ |    | |__| | (_| | | | | | |  __/
#  |_|  |_|_|\__, |_| |_|\___|_|    |______\___/ \_/\_/ \___|_|     \_____|\__,_|_| |_| |_|\___|
#             __/ |
#            |___/
#
#
#
# Compare 1:   T-series  , a  Music Label & movie Studio  , from  Inida
#
#  __      __   _____
#  \ \    / /  / ____|
#   \ \  / /  | (___
#    \ \/ /    \___ \
#     \  /     ____) |
#      \/     |_____/
#
#
# Compare 2:   Jennifer Lopez  , a  Musician and Actress  , from  United States
# ---------------------------------------------------------------------------
# ...

# %%
print(game_art.game_logo)
score = 0



def display_account(account):
    name = account['name']
    description = account['description']
    country = account['country']
    return f" {name} , a {description} , from {country}"


def check_answer( followers_count_1 , followers_count_2 , guess):
    if followers_count_1 < followers_count_2:
        if guess == 1: ##return guess==2
            return False
        else:
            return True
        
    else:
        if guess==1:
            return True
        else:
            return False



continue_flag = True
while continue_flag:
    account1 = random.choice(game_database.data)
    account2 = random.choice(game_database.data)

    print(f"\nCompare 1: {display_account(account1)}")  # function call
    print(game_art.vs)
    print(f"Compare 2: {display_account(account2)}")  # function call 


    guess = int(input("who has more Followers? 1 or 2: "))

    followers_count_1 = account1['follower_count']
    followers_count_2 = account2['follower_count']



    is_corrrect = check_answer(followers_count_1 , followers_count_2 , guess )  ## function call

    if is_corrrect == True:
        score +=1
        print(f"you are right. Your score is: {score}")
        
    else:
        print(f"You are wrong.. your final score is: {score}")
        continue_flag = False
# Out:
#   _    _ _       _                 _                               _____
#  | |  | (_)     | |               | |                             / ____|
#  | |__| |_  __ _| |__   ___ _ __  | |     _____      _____ _ __  | |  __  __ _ _ __ ___   ___
#  |  __  | |/ _` | '_ \ / _ \ '__| | |    / _ \ \ /\ / / _ \ '__| | | |_ |/ _` | '_ ` _ \ / _ \
#  | |  | | | (_| | | | |  __/ |    | |___| (_) \ V  V /  __/ |    | |__| | (_| | | | | | |  __/
#  |_|  |_|_|\__, |_| |_|\___|_|    |______\___/ \_/\_/ \___|_|     \_____|\__,_|_| |_| |_|\___|
#             __/ |
#            |___/
#
#
#
# Compare 1:   NASA  , a  Space Agency  , from  United States
#
#  __      __   _____
#  \ \    / /  / ____|
#   \ \  / /  | (___
#    \ \/ /    \___ \
#     \  /     ____) |
#      \/     |_____/
#
#
# Compare 2:   NASA  , a  Space Agency  , from  United States
# you are right. Your score is: 1
#
# Compare 1:   Jennifer Lopez  , a  Musician and Actress  , from  United States
#
#  __      __   _____
# ...

# %%
print(game_art.game_logo)
score = 0



def display_account(account):
    name = account['name']
    description = account['description']
    country = account['country']
    return f" {name} , a {description} , from {country}"


def check_answer( followers_count_1 , followers_count_2 , guess):
    if followers_count_1 < followers_count_2:
        if guess == 1: ##return guess==2
            return False
        else:
            return True
        
    else:
        if guess==1:
            return True
        else:
            return False




account2 = random.choice(game_database.data)

continue_flag = True
while continue_flag:
    account1 = account2
    account2 = random.choice(game_database.data)
    
    
    ## handling duplicate
    while account1==account2:
        account2 = random.choice(game_database.data)

    print(f"\nCompare 1: {display_account(account1)}")  # function call
    print(game_art.vs)
    print(f"Compare 2: {display_account(account2)}")  # function call 


    guess = int(input("who has more Followers? 1 or 2: "))

    followers_count_1 = account1['follower_count']
    followers_count_2 = account2['follower_count']



    is_corrrect = check_answer(followers_count_1 , followers_count_2 , guess )  ## function call

    if is_corrrect == True:
        score +=1
        print(f"you are right. Your score is: {score}")
        
    else:
        print(f"You are wrong.. your final score is: {score}")
        continue_flag = False
# Out:
#   _    _ _       _                 _                               _____
#  | |  | (_)     | |               | |                             / ____|
#  | |__| |_  __ _| |__   ___ _ __  | |     _____      _____ _ __  | |  __  __ _ _ __ ___   ___
#  |  __  | |/ _` | '_ \ / _ \ '__| | |    / _ \ \ /\ / / _ \ '__| | | |_ |/ _` | '_ ` _ \ / _ \
#  | |  | | | (_| | | | |  __/ |    | |___| (_) \ V  V /  __/ |    | |__| | (_| | | | | | |  __/
#  |_|  |_|_|\__, |_| |_|\___|_|    |______\___/ \_/\_/ \___|_|     \_____|\__,_|_| |_| |_|\___|
#             __/ |
#            |___/
#
#
#
# Compare 1:   Shakira  , a  Musician  , from  Colombia
#
#  __      __   _____
#  \ \    / /  / ____|
#   \ \  / /  | (___
#    \ \/ /    \___ \
#     \  /     ____) |
#      \/     |_____/
#
#
# Compare 2:   Kylie Gener  , a  Reality TV personality and Businesswoman and self-made Billionaire  , from  United states
# you are right. Your score is: 1
#
# ...

# %%
## clearing previous output only in python .py file

import os


print(game_art.game_logo)
score = 0



def display_account(account):
    name = account['name']
    description = account['description']
    country = account['country']
    return f" {name} , a {description} , from {country}"


def check_answer( followers_count_1 , followers_count_2 , guess):
    if followers_count_1 < followers_count_2:
        if guess == 1: ##return guess==2
            return False
        else:
            return True
        
    else:
        if guess==1:
            return True
        else:
            return False




account2 = random.choice(game_database.data)

continue_flag = True
while continue_flag:
    account1 = account2
    account2 = random.choice(game_database.data)
    
    
    ## handling duplicate
    while account1==account2:
        account2 = random.choice(game_database.data)

    print(f"\nCompare 1: {display_account(account1)}")  # function call
    print(game_art.vs)
    print(f"Compare 2: {display_account(account2)}")  # function call 


    guess = int(input("who has more Followers? 1 or 2: "))

    followers_count_1 = account1['follower_count']
    followers_count_2 = account2['follower_count']



    is_corrrect = check_answer(followers_count_1 , followers_count_2 , guess )  ## function call
    os.system('cls')
    print(game_art.game_logo)
    

    if is_corrrect == True:
        score +=1
        print(f"you are right. Your score is: {score}")
        
    else:
        print(f"You are wrong.. your final score is: {score}")
        continue_flag = False
