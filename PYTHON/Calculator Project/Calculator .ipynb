# %%
def add(a,b):
    return a+b

def sutract(a,b):
    return a-b

def multiply(a,b):
    return a*b

def divide(a,b):
    return a/b




operations_dict ={  
    "+": add,
    "-": sutract,
    "*": multiply,
    "/": divide
}



number1  = int(input("Enter First Number: "))
print("Number1: ", number1)

print("\nlist of Symbol:" )
for symbol in operations_dict:
    print(symbol)

op_symbol  = input("Pick an operation: ")
print("\nop_symbol:", op_symbol)

number2 = int(input("Enter next number"))
print("\nNumber2: ", number2)

calculator_function = operations_dict[op_symbol]

output =calculator_function(number1, number2)

print(f"{number1}{op_symbol}{number2} = {output}")
# Out:
# Number1:  1
#
# list of Symbol:
# +
# -
# *
# /
#
# op_symbol: +
#
# Number2:  6
# 1+6 = 7

# %%
def add(a,b):
    return a+b

def sutract(a,b):
    return a-b

def multiply(a,b):
    return a*b

def divide(a,b):
    return a/b




operations_dict ={  
    "+": add,
    "-": sutract,
    "*": multiply,
    "/": divide
}



number1  = int(input("Enter First Number: "))
print("Number1: ", number1)

print("\nlist of Symbol:" )
for symbol in operations_dict:
    print(symbol)

continue_flag = True
while continue_flag:
    op_symbol  = input("Pick an operation: ")
    print("\nop_symbol:", op_symbol)

    number2 = int(input("Enter next number"))
    print("\nNumber2: ", number2)

    calculator_function = operations_dict[op_symbol]

    output =calculator_function(number1, number2)
    print(f"\nAnswer: {number1} {op_symbol} {number2} = {output}")

    should_continue= input(f"Enter 'y' to continue calculation with {output} or 'n' to exit").lower()
    print("should_continue:",should_continue)

    if should_continue=='y':
        number1=output
        
    else:
        continue_flag = False
        print("bye")
# Out:
# Number1:  1
#
# list of Symbol:
# +
# -
# *
# /
#
# op_symbol: +
#
# Number2:  2
#
# Answer: 1 + 2 = 3
# should_continue: m
# bye

# %%
def add(a,b):
    return a+b

def sutract(a,b):
    return a-b

def multiply(a,b):
    return a*b

def divide(a,b):
    return a/b




operations_dict ={  
    "+": add,
    "-": sutract,
    "*": multiply,
    "/": divide
}



number1  = int(input("Enter First Number: "))
print("Number1: ", number1)

print("\nlist of Symbol:" )
for symbol in operations_dict:
    print(symbol)

continue_flag = True
while continue_flag:
    op_symbol  = input("Pick an operation: ")
    print("\nop_symbol:", op_symbol)

    number2 = int(input("Enter next number"))
    print("\nNumber2: ", number2)

    calculator_function = operations_dict[op_symbol]

    output =calculator_function(number1, number2)
    print(f"\nAnswer: {number1} {op_symbol} {number2} = {output}")

    should_continue= input(f"Enter 'y' to continue calculation with {output} or 'n' to start a new connection or 'x' exit").lower()
    print("should_continue:",should_continue)

    if should_continue=='y':
        number1=output
        
    else:
        continue_flag = False
        print("bye")

# %%
def add(a,b):
    return a+b

def sutract(a,b):
    return a-b

def multiply(a,b):
    return a*b

def divide(a,b):
    return a/b




operations_dict ={  
    "+": add,
    "-": sutract,
    "*": multiply,
    "/": divide
}


def calculator():
    number1  = int(input("Enter First Number: "))
    print("\nNumber1: ", number1)

    print("list of Symbol:" )
    for symbol in operations_dict:
        print(symbol)

    continue_flag = True
    while continue_flag:
        op_symbol  = input("Pick an operation: ")
        print("op_symbol:", op_symbol)

        number2 = int(input("Enter next number"))
        print("Number2: ", number2)

        calculator_function = operations_dict[op_symbol]

        output =calculator_function(number1, number2)
        print(f"Answer: {number1} {op_symbol} {number2} = {output}")

        should_continue= input(f"Enter 'y' to continue calculation with {output} or 'n' to start a new connection or 'x' exit").lower()
        print(f"should_continue with {output} = {should_continue}")

        if should_continue=='y':
            number1=output
            
        elif should_continue=='n':
            continue_flag=False
            calculator()
        
            
        else :
            continue_flag = False
            print("bye")
            
calculator()
# Out:
# Number1:  1
# list of Symbol:
# +
# -
# *
# /
# op_symbol: +
# Number2:  5
# Answer: 1 + 5 = 6
# should_continue with 6 = n
#
# Number1:  10
# list of Symbol:
# +
# -
# *
# /
# op_symbol: +45
# Number2:  234
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 60
#      57             continue_flag = False
#      58             print("bye")
# ---> 60 calculator()
#
# Cell In[34], line 53, in calculator()
#      51 elif should_continue=='n':
#      52     continue_flag=False
# ---> 53     calculator()
#      56 else :
#      57     continue_flag = False
#
# Cell In[34], line 40, in calculator()
#      37 number2 = int(input("Enter next number"))
#      38 print("Number2: ", number2)
# ---> 40 calculator_function = operations_dict[op_symbol]
#      42 output =calculator_function(number1, number2)
# ...

# %%
## clearing terminal onlly in python not in notebbbok

import os

def add(a,b):
    return a+b

def sutract(a,b):
    return a-b

def multiply(a,b):
    return a*b

def divide(a,b):
    return a/b




operations_dict ={  
    "+": add,
    "-": sutract,
    "*": multiply,
    "/": divide
}


def calculator():
    number1  = int(input("Enter First Number: "))
    print("\nNumber1: ", number1)

    print("list of Symbol:" )
    for symbol in operations_dict:
        print(symbol)

    continue_flag = True
    while continue_flag:
        op_symbol  = input("Pick an operation: ")
        print("op_symbol:", op_symbol)

        number2 = int(input("Enter next number"))
        print("Number2: ", number2)

        calculator_function = operations_dict[op_symbol]

        output =calculator_function(number1, number2)
        print(f"Answer: {number1} {op_symbol} {number2} = {output}")

        should_continue= input(f"Enter 'y' to continue calculation with {output} or 'n' to start a new connection or 'x' exit").lower()
        print(f"should_continue with {output} = {should_continue}")

        if should_continue=='y':
            number1=output
            
        elif should_continue=='n':
            continue_flag=False
            os.system('cls')
            calculator()
        
            
        else :
            continue_flag = False
            print("bye")
            
calculator()

# %%
# Changing int value into float

import os

def add(a,b):
    return a+b

def sutract(a,b):
    return a-b

def multiply(a,b):
    return a*b

def divide(a,b):
    return a/b




operations_dict ={  
    "+": add,
    "-": sutract,
    "*": multiply,
    "/": divide
}


def calculator():
    number1  = float(input("Enter First Number: "))
    print("\nNumber1: ", number1)

    print("list of Symbol:" )
    for symbol in operations_dict:
        print(symbol)

    continue_flag = True
    while continue_flag:
        op_symbol  = input("Pick an operation: ")
        print("op_symbol:", op_symbol)

        number2 = float(input("Enter next number"))
        print("Number2: ", number2)

        calculator_function = operations_dict[op_symbol]

        output =calculator_function(number1, number2)
        print(f"Answer: {number1} {op_symbol} {number2} = {output}")

        should_continue= input(f"Enter 'y' to continue calculation with {output} or 'n' to start a new connection or 'x' exit").lower()
        print(f"should_continue with {output} = {should_continue}")

        if should_continue=='y':
            number1=output
            
        elif should_continue=='n':
            continue_flag=False
            os.system('cls')
            calculator()
        
            
        else :
            continue_flag = False
            print("bye")
            
calculator()
