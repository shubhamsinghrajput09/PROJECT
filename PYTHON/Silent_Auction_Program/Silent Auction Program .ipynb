# %%
def find_winner(bidder_details):
    highest_bid =0
    winner = ""
    
    for bidder in bidder_details:
        bidding_price = bidder_details[bidder]
        
        if bidding_price>highest_bid:
            highest_bid=bidding_price
            winner=bidder
    print(f"The winner is  {winner} with a bid price of {highest_bid}")





bidder_data={}

end_of_bidding = False
while not end_of_bidding:
    
    name = input("what is your name")
    print(f"what is your name: {name}")
    
    price  = int(input("what is your bid?:"))
    print(f"what is your bid?: {price}")

    bidder_data[name]=price

    more_bidders = input("are there more bidders? Type 'yes' or 'no': ").lower()

    if more_bidders=='no':
        end_of_bidding=True
        find_winner(bidder_data)

# %%
import os  ## run this in python vs.code not in jupyter to see the changes

print("****** welcome to silnt Auction Program ******")
def find_winner(bidder_details):
    highest_bid =0
    winner = ""
    
    for bidder in bidder_details:
        bidding_price = bidder_details[bidder]
        
        if bidding_price>highest_bid:
            highest_bid=bidding_price
            winner=bidder
    print(f"The winner is  {winner} with a bid price of {highest_bid}")





bidder_data={}

end_of_bidding = False
while not end_of_bidding:
    
    name = input("what is your name")
    print(f"what is your name: {name}")
    
    price  = int(input("what is your bid?:"))
    print(f"what is your bid?: {price}")

    bidder_data[name]=price

    more_bidders = input("are there more bidders? Type 'yes' or 'no': ").lower()

    if more_bidders=='no':
        end_of_bidding=True
        print('list of all the bidders: ',bidder_data)
        find_winner(bidder_data)
    
    elif more_bidders== 'yes':
        os.system('cls scr')              ## it will clear the terminal
