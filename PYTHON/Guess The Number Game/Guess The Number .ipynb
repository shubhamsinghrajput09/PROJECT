# %%
import random

EASY_ATTEMPTS =10
HARD_ATTEMPTS =5


def set_difficulty(level_chossen):
    if level_chossen == 'easy':
        return EASY_ATTEMPTS
    
    elif level_chossen =='hard':
        return HARD_ATTEMPTS
    
    else:
        return 10
    


def check_answer(guesses_number, answer , attempts):
    if guesses_number < answer:
        print("it's too low")
        return attempts-1
        
    elif guesses_number>answer:
        print("it's too high ")
        return attempts-1
    else:
        print(f"\nyou guess is right... The answer is {answer}")




def game():
    
    
    
    print("let me guess a number between 1 to 50")

    answer = random.randint(1,50)
    print(answer)

    choose_difficulty = input("choose level of difficulty.... Type 'easy' or 'hard' : ").lower()
    attempts = set_difficulty(choose_difficulty)






    guesses_number = 0
    while guesses_number!= answer:
        print(f"\nyou have {attempts} attempts remaining to guess the number")
        guesses_number = int(input("guess a number :"))
        print("guesed no is:" , guesses_number)

        attempts = check_answer(guesses_number=guesses_number ,answer=answer , attempts= attempts)

        if attempts == 0:
            print("\nyou are out of gusses...  you lose")
            return
        elif guesses_number!=answer:
            print("guess again")
            
            
            
game()
# Out:
# let me guess a number between 1 to 50
# 36
#
# you have 5 attempts remaining to guess the number
# guesed no is: 4
# it's too low
# guess again
#
# you have 4 attempts remaining to guess the number
# guesed no is: 1
# it's too low
# guess again
#
# you have 3 attempts remaining to guess the number
# guesed no is: 1
# it's too low
# guess again
#
# you have 2 attempts remaining to guess the number
# guesed no is: 1
# it's too low
# guess again
#
# you have 1 attempts remaining to guess the number
# guesed no is: 1
# it's too low
#
# you are out of gusses...  you lose

# %%
logo = """

   _____                       _______ _            _   _                 _               
  / ____|                     |__   __| |          | \ | |               | |              
 | |  __ _   _  ___  ___ ___     | |  | |__   ___  |  \| |_   _ _ __ ___ | |__   ___ _ __ 
 | | |_ | | | |/ _ \/ __/ __|    | |  | '_ \ / _ \ | . ` | | | | '_ ` _ \| '_ \ / _ \ '__|
 | |__| | |_| |  __/\__ \__ \    | |  | | | |  __/ | |\  | |_| | | | | | | |_) |  __/ |   
  \_____|\__,_|\___||___/___/    |_|  |_| |_|\___| |_| \_|\__,_|_| |_| |_|_.__/ \___|_|   
                                                                                          
                                                                                          

"""
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24036\4179602882.py:4: SyntaxWarning: invalid escape sequence '\ '
#   / ____|                     |__   __| |          | \ | |               | |

# %%
import random

EASY_ATTEMPTS =10
HARD_ATTEMPTS =5


def set_difficulty(level_chossen):
    if level_chossen == 'easy':
        return EASY_ATTEMPTS
    
    elif level_chossen =='hard':
        return HARD_ATTEMPTS
    
    else:
        return 10
    


def check_answer(guesses_number, answer , attempts):
    if guesses_number < answer:
        print("it's too low")
        return attempts-1
        
    elif guesses_number>answer:
        print("it's too high ")
        return attempts-1
    else:
        print(f"\nyou guess is right... The answer is {answer}")




def game():
    
    # global logo
    print(logo)
    
    print("let me guess a number between 1 to 50")

    answer = random.randint(1,50)


    choose_difficulty = input("choose level of difficulty.... Type 'easy' or 'hard' : ").lower()
    attempts = set_difficulty(choose_difficulty)






    guesses_number = 0
    while guesses_number!= answer:
        print(f"\nyou have {attempts} attempts remaining to guess the number")
        guesses_number = int(input("guess a number :"))
        print("guesed no is:" , guesses_number)

        attempts = check_answer(guesses_number=guesses_number ,answer=answer , attempts= attempts)

        if attempts == 0:
            print("\nyou are out of gusses...  you lose")
            return
        elif guesses_number!=answer:
            print("guess again")
            
            
            
game()
# Out:
#    _____                       _______ _            _   _                 _
#   / ____|                     |__   __| |          | \ | |               | |
#  | |  __ _   _  ___  ___ ___     | |  | |__   ___  |  \| |_   _ _ __ ___ | |__   ___ _ __
#  | | |_ | | | |/ _ \/ __/ __|    | |  | '_ \ / _ \ | . ` | | | | '_ ` _ \| '_ \ / _ \ '__|
#  | |__| | |_| |  __/\__ \__ \    | |  | | | |  __/ | |\  | |_| | | | | | | |_) |  __/ |
#   \_____|\__,_|\___||___/___/    |_|  |_| |_|\___| |_| \_|\__,_|_| |_| |_|_.__/ \___|_|
#
#
#
#
# let me guess a number between 1 to 50
# 27
#
# you have 10 attempts remaining to guess the number
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 67
#      62         elif guesses_number!=answer:
#      63             print("guess again")
# ---> 67 game()
#
# Cell In[33], line 54, in game()
#      52 while guesses_number!= answer:
# ...

# %%
import random

EASY_ATTEMPTS =10
HARD_ATTEMPTS =5


def set_difficulty(level_chossen):
    if level_chossen == 'easy':
        return EASY_ATTEMPTS
    
    elif level_chossen =='hard':
        return HARD_ATTEMPTS
    
    else:
        return 
    


def check_answer(guesses_number, answer , attempts):
    if guesses_number < answer:
        print("it's too low")
        return attempts-1
        
    elif guesses_number>answer:
        print("it's too high ")
        return attempts-1
    else:
        print(f"\nyou guess is right... The answer is {answer}")




def game():
    
    # global logo
    print(logo)
    
    print("let me guess a number between 1 to 50")

    answer = random.randint(1,50)


    choose_difficulty = input("choose level of difficulty.... Type 'easy' or 'hard' : ").lower()
    attempts = set_difficulty(choose_difficulty)
    if attempts!= EASY_ATTEMPTS and attempts!=HARD_ATTEMPTS:
        print("you have entered wrong difiiculty level.. Play again!!")
        return





    guesses_number = 0
    while guesses_number!= answer:
        print(f"\nyou have {attempts} attempts remaining to guess the number")
        guesses_number = int(input("guess a number :"))
        print("guesed no is:" , guesses_number)

        attempts = check_answer(guesses_number=guesses_number ,answer=answer , attempts= attempts)

        if attempts == 0:
            print("\nyou are out of gusses...  you lose")
            return
        elif guesses_number!=answer:
            print("guess again")
            
            
            
game()
# Out:
#    _____                       _______ _            _   _                 _
#   / ____|                     |__   __| |          | \ | |               | |
#  | |  __ _   _  ___  ___ ___     | |  | |__   ___  |  \| |_   _ _ __ ___ | |__   ___ _ __
#  | | |_ | | | |/ _ \/ __/ __|    | |  | '_ \ / _ \ | . ` | | | | '_ ` _ \| '_ \ / _ \ '__|
#  | |__| | |_| |  __/\__ \__ \    | |  | | | |  __/ | |\  | |_| | | | | | | |_) |  __/ |
#   \_____|\__,_|\___||___/___/    |_|  |_| |_|\___| |_| \_|\__,_|_| |_| |_|_.__/ \___|_|
#
#
#
#
# let me guess a number between 1 to 50
# you have entered wrong difiiculty level.. Play again!!
