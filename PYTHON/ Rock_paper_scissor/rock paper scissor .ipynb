# %%
import random

# %%
# rock----0
# paper ----1
# scissor-----2

# %%
computer_choice = random.randint(0,2)

print("choices are\n1 for Rock Press-- 0\n2 for Paper Presss-- 1\n3 for Scissors Press---2 ")


user_choice = int(input('enter your chioce---- '))

# if computer_choice == 0 &  user_choice ==0 or  computer_choice == 1 &  user_choice ==1 or computer_choice == 2 &  user_choice ==2  :
#     print('Draw')
    
if computer_choice == 0 &  user_choice ==1 :
    print('computer win')
    
elif computer_choice == 0 &  user_choice ==2 :
    print('user win')
    
elif computer_choice == 1 &  user_choice ==0 :
    print('user win')
    
elif computer_choice == 1 &  user_choice ==2 :
    print('computer win')
    
elif computer_choice == 2 &  user_choice ==0 :
    print('computer win')
    
elif computer_choice == 2 &  user_choice ==1 :
    print('user win')
    
else:
    print('Draw')
# Out:
# choices are
# 1 for Rock Press-- 0
# 2 for Paper Presss-- 1
# 3 for Scissors Press---2
# Draw

# %%
print("choices are\n1 for Rock Press-- 0\n2 for Paper Presss-- 1\n3 for Scissors Press---2 ")

user_choice = int(input('enter your chioce---- '))
if user_choice >= 3 or user_choice <0:
    print("you have entered  invalid number , you losse")

else:
    computer_choice = random.randint(0,2)
    print('\ncomputer choice: ', computer_choice)
    
    print('user choice:', user_choice)
    
    if computer_choice == user_choice:
        print('\nit is a Draw')
        
    elif computer_choice == 0 &  user_choice ==2:
        print('\nyou lose')
        
    elif computer_choice == 2 &  user_choice ==0:
        print('\nyou win')
    
    elif computer_choice> user_choice:   ## maintain order 
        print('\nyou lose')
        
    elif computer_choice  < user_choice :
        print('\nyou win')
# Out:
# choices are
# 1 for Rock Press-- 0
# 2 for Paper Presss-- 1
# 3 for Scissors Press---2
#
# computer choice:  2
# user choice: 1
#
# you lose

# %%
print("choices are\n1 for Rock Press-- 0\n2 for Paper Presss-- 1\n3 for Scissors Press---2")

while True:
    user_choice = int(input('enter your chioce---- '))



    if user_choice >= 3 or user_choice <0:
        print("you have entered  invalid number , you losse")
        break

    else:
        computer_choice = random.randint(0,2)
        print('\ncomputer choice: ', computer_choice)
        
        print('user choice:', user_choice)
        
        if computer_choice == user_choice:
            print('\nit is a Draw')
            
        elif computer_choice == 0 &  user_choice ==2:
            print('\nyou lose')
            
        elif computer_choice == 2 &  user_choice ==0:
            print('\nyou win')
        
        elif computer_choice> user_choice:   ## maintain order 
            print('\nyou lose')
            
        elif computer_choice  < user_choice :
            print('\nyou win')
# Out:
# choices are
# 1 for Rock Press-- 0
# 2 for Paper Presss-- 1
# 3 for Scissors Press---2
#
# computer choice:  1
# user choice: 1
#
# it is a Draw
#
# computer choice:  1
# user choice: 0
#
# you lose
#
# computer choice:  0
# user choice: 2
#
# you win
# you have entered  invalid number , you losse

# %%
rock ='''
          _ _ _ _
--------'   _ _ _ )   
          (_ _ _ _)
           (_ _ _ )
            (_ _ _)
-------._ _ _ (_ _)

'''

paper = '''

          _ _  _
--------'   _ _  _ )   
             _ _ _ _ _)
             _ _ _ _ _ )
            _ _ _ _ _)
-------._ _ _ _ _)

'''
scissor = '''


          _ _ _ _
--------'   _ _ _ _ )   
            _ _ _ _ _ _ _)
            _ _ _ _ _ _ _ )
            (_ _ _ _)
-------._ _ (_ _ _)


'''
game_image = [rock , paper ,scissor]


print("choices are\n1 for Rock Press-- 0\n2 for Paper Presss-- 1\n3 for Scissors Press---2 ")

user_choice = int(input('enter your chioce---- '))

if user_choice >= 3 or user_choice <0:
    print("you have entered  invalid number , you losse")

else:
    
    computer_choice = random.randint(0,2)
    print('\ncomputer choice: ', game_image[computer_choice])
    
    print('user choice:', game_image[user_choice])
    
    
    if computer_choice == user_choice:
        print('\nit is a Draw')
        
    elif computer_choice == 0 &  user_choice ==2:
        print('\nyou lose')
        
    elif computer_choice == 2 &  user_choice ==0:
        print('\nyou win')
    
    elif computer_choice> user_choice:   ## maintain order 
        print('\nyou lose')
        
    elif computer_choice  < user_choice :
        print('\nyou win')
# Out:
# choices are
# 1 for Rock Press-- 0
# 2 for Paper Presss-- 1
# 3 for Scissors Press---2
#
# computer choice:
#
#
#           _ _ _ _
# --------'   _ _ _ _ )
#             _ _ _ _ _ _ _)
#             _ _ _ _ _ _ _ )
#             (_ _ _ _)
# -------._ _ (_ _ _)
#
#
#
# user choice:
#           _ _ _ _
# --------'   _ _ _ )
#           (_ _ _ _)
#            (_ _ _ )
#             (_ _ _)
# -------._ _ _ (_ _)
#
#
#
# you lose
